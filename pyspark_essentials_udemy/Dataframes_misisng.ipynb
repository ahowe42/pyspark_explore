# %%
import pandas as pd
import numpy as np
import datetime as dt

import findspark
findspark.init()
import pyspark
from pyspark.sql import SparkSession
from pyspark.sql.functions import *#avg, count, expr
from pyspark.sql.types import *

# %%
# initialize
sc = pyspark.SparkContext()
spark = SparkSession(sc)
spark.sparkContext.appName = 'handlingMissing'
# show the number of cores
print('%d cores'%spark._jsc.sc().getExecutorMemoryStatus().keySet().size())
spark
# Out:
# 1 cores
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://192.168.150.128:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.1.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>handlingMissing</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
# load the data
fil = '../data/zomato.csv'
schem = StructType([StructField('url', StringType()), StructField('address', StringType()),
                    StructField('name', StringType()), StructField('online_order', StringType()),
                    StructField('book_table', StringType()), StructField('rate', StringType()),
                    StructField('votes', IntegerType()), StructField('phone', StringType()),
                    StructField('location', StringType()), StructField('rest_type', StringType()),
                    StructField('dish_liked', StringType()), StructField('cuisines', StringType()),
                    StructField('approx_cost(for two people)', FloatType()), StructField('reviews_list', StringType()),
                    StructField('menu_item', StringType()), StructField('listed_in(type)', StringType()),
                    StructField('listed_in(city)', StringType())])
zomato = spark.read.format('csv').options(header=True).schema(schem).load(fil)\
    .withColumn('onlineOrder', col('online_order')=='Yes').withColumn('bookTable', col('online_order')=='Yes')\
    .drop('online_order', 'book_table')

# talk
display(zomato.limit(10).toPandas())
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1                                    +91 9743772233"
# 2  https://www.zomato.com/bangalore/spice-elephan...
# 3  https://www.zomato.com/SanchurroBangalore?cont...
# 4  https://www.zomato.com/bangalore/addhuri-udupi...
# 5  https://www.zomato.com/bangalore/grand-village...
# 6                                    +91 9901210005"
# 7  https://www.zomato.com/bangalore/timepass-dinn...
# 8                                    +91 9980063005"
# 9  https://www.zomato.com/bangalore/rosewood-inte...
#
#                                              address  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1                                       Banashankari
# 2  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 3  1112, Next to KIMS Medical College, 17th Cross...
# 4  1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 5  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# 6                                       Basavanagudi
# 7  37, 5-1, 4th Floor, Bosco Court, Gandhi Bazaar...
# 8                                       Basavanagudi
# 9  19/1, New Timberyard Layout, Beside Satellite ...
#
#                                               name   rate  votes  \
# 0                                            Jalsa  4.1/5  775.0
# 1                                    Casual Dining    800    NaN
# 2                                   Spice Elephant  4.1/5  787.0
# 3                                  San Churro Cafe  3.8/5  918.0
# 4                            Addhuri Udupi Bhojana  3.7/5   88.0
# 5                                    Grand Village  3.8/5  166.0
# 6                                    Casual Dining    600    NaN
# 7                                  Timepass Dinner  3.8/5  286.0
# 8                                    Casual Dining    600    NaN
# 9  Rosewood International Hotel - Bar & Restaurant  3.6/5    8.0
#
#             phone                                           location  \
# 0    080 42297555                                               None
# 1    ('Rated 4.0'   'RATED\n  You canÃ\x83Ã\x83Ã\x82Ã\x82Ã\x...
# 2    080 41714161                                       Banashankari
# 3  +91 9663487993                                       Banashankari
# 4  +91 9620009302                                       Banashankari
# 5  +91 8026612447                                               None
# 6              []                                             Buffet
# 7  +91 9980040002                                               None
# 8              []                                             Buffet
# 9  +91 9731716688                                               None
#
#              rest_type                                         dish_liked  \
# 0                 None                                               None
# 1         ('Rated 5.0'   'RATED\n  Overdelighted by the service and fo...
# 2        Casual Dining  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 3  Cafe, Casual Dining  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 4          Quick Bites                                        Masala Dosa
# 5                 None                                               None
# 6         Banashankari                                               None
# 7                 None                                               None
# 8         Banashankari                                               None
# 9                 None                                               None
#
#                       cuisines  approx_cost(for two people)  \
# 0                         None                          NaN
# 1                 ('Rated 4.0'                          NaN
# 2  Chinese, North Indian, Thai                        800.0
# 3       Cafe, Mexican, Italian                        800.0
# 4   South Indian, North Indian                        300.0
# 5                         None                          NaN
# 6                         None                          NaN
# 7                         None                          NaN
# 8                         None                          NaN
# 9                         None                          NaN
#
#                                         reviews_list  \
# 0                                               None
# 1                                       ('Rated 4.0'
# 2  "[('Rated 4.0', 'RATED\n  Had been here for di...
# 3  "[('Rated 3.0', ""RATED\n  Ambience is not tha...
# 4  "[('Rated 4.0', ""RATED\n  Great food and prop...
# 5                                               None
# 6                                               None
# 7                                               None
# 8                                               None
# 9                                               None
#
#                                            menu_item  \
# 0                                               None
# 1   'RATED\n  The place is nice and comfortable. ...
# 2  rice was well cooked and overall was great\n\n...
# 3                                       ('Rated 3.0'
# 4                                       ('Rated 2.0'
# 5                                               None
# 6                                               None
# 7                                               None
# 8                                               None
# 9                                               None
#
#                                      listed_in(type)  \
# 0                                               None
# 1                                       ('Rated 4.0'
# 2                                       ('Rated 5.0'
# 3   ""RATED\n \nWent there for a quick bite with ...
# 4   'RATED\n  Reached the place at 3pm on Saturda...
# 5                                               None
# 6                                               None
# 7                                               None
# 8                                               None
# 9                                               None
#
#                                      listed_in(city)  onlineOrder  bookTable
# 0                                               None         True       True
# 1   'RATED\n  The place is nice and comfortable. ...        False      False
# 2   'RATED\n  This place just cool ? with good am...         True       True
# 3   pasta churros and lasagne.\n\nNachos were pat...         True       True
# 4                                       ('Rated 4.0'        False      False
# 5                                               None        False      False
# 6                                               None        False      False
# 7                                               None         True       True
# 8                                               None        False      False
# 9                                               None        False      False

# %%
# count nulls per column
cnt = zomato.count()
nullCounts = {colm:zomato.select(colm).where(col(colm).isNull()).count() for colm in zomato.columns}
nullCounts = {colm:(ncnt, ncnt/cnt) for (colm, ncnt) in nullCounts.items()}
print(nullCounts)
# Out:
# {'url': (0, 0.0), 'address': (0, 0.0), 'name': (85, 0.0011849993029415865), 'rate': (7775, 0.10839258329848041), 'votes': (20018, 0.2790743064268786), 'phone': (1227, 0.017105813467168548), 'location': (20054, 0.27957618848459503), 'rest_type': (20165, 0.281123658162554), 'dish_liked': (46841, 0.6530182629304335), 'cuisines': (27305, 0.3806635996096473), 'approx_cost(for two people)': (43611, 0.6079882894186532), 'reviews_list': (28185, 0.3929318276871602), 'menu_item': (28611, 0.398870765370138), 'listed_in(type)': (28983, 0.4040568799665412), 'listed_in(city)': (29344, 0.4090896417119755), 'onlineOrder': (8111, 0.11307681583716715), 'bookTable': (8111, 0.11307681583716715)}

# %%
# pretty print
nullCountsDF = pd.DataFrame(nullCounts).T.reset_index(drop=False).sort_values(1, ascending=False)
nullCountsDF.columns = ['Column', 'Freq.', 'Rel. Freq.']
nullCountsDF = nullCountsDF.merge(pd.DataFrame([[colm.name, colm.dataType] for colm in zomato.schema], columns=['Column', 'Type']),
                                how='inner', on=['Column'])
display(nullCountsDF)
# Out:
#                          Column    Freq.  Rel. Freq.         Type
# 0                    dish_liked  46841.0    0.653018   StringType
# 1   approx_cost(for two people)  43611.0    0.607988    FloatType
# 2               listed_in(city)  29344.0    0.409090   StringType
# 3               listed_in(type)  28983.0    0.404057   StringType
# 4                     menu_item  28611.0    0.398871   StringType
# 5                  reviews_list  28185.0    0.392932   StringType
# 6                      cuisines  27305.0    0.380664   StringType
# 7                     rest_type  20165.0    0.281124   StringType
# 8                      location  20054.0    0.279576   StringType
# 9                         votes  20018.0    0.279074  IntegerType
# 10                  onlineOrder   8111.0    0.113077  BooleanType
# 11                    bookTable   8111.0    0.113077  BooleanType
# 12                         rate   7775.0    0.108393   StringType
# 13                        phone   1227.0    0.017106   StringType
# 14                         name     85.0    0.001185   StringType
# 15                      address      0.0    0.000000   StringType
# 16                          url      0.0    0.000000   StringType

# %% [markdown]
# ### dropping nulls

# %%
# drop all rows with all missing data
noNull = zomato.dropna(how='all')
print('Dataset reduced from %d to %d'%(cnt, noNull.count()))
# Out:
# Dataset reduced from 71730 to 71730

# %%
# drop all rows with any missing data
noNull = zomato.dropna()
print('Dataset reduced from %d to %d'%(cnt, noNull.count()))
# Out:
# Dataset reduced from 71730 to 8606

# %%
# drop all rows with more than numCols-N missing
N = 8
noNull = zomato.dropna(thresh = N)
print('Dataset reduced from %d to %d'%(cnt, noNull.count()))
# Out:
# Dataset reduced from 71730 to 65842

# %%
# drop rows only if null in votes
noNull = zomato.dropna(subset = 'votes')
print('Dataset reduced from %d to %d'%(cnt, noNull.count()))
# Out:
# Dataset reduced from 71730 to 51712

# %% [markdown]
# ### filling nulls

# %%
filld = zomato.fillna({'dish_liked':'MISSING', 'approx_cost(for two people)':42, 'onlineOrder':False})
filld.select('dish_liked', 'approx_cost(for two people)', 'onlineOrder').show(truncate=False)
# Out:
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------+-----------+
# |dish_liked                                                                                                                                                                                                                                                       |approx_cost(for two people)|onlineOrder|
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------+-----------+
# |MISSING                                                                                                                                                                                                                                                          |42.0                       |true       |
# | 'RATED\n  Overdelighted by the service and food provided at this place. A royal and ethnic atmosphere builds a strong essence of being in India and also the quality and taste of food is truly authentic. I would totally recommend to visit this place once.')|42.0                       |false      |
# |Momos, Lunch Buffet, Chocolate Nirvana, Thai Green Curry, Paneer Tikka, Dum Biryani, Chicken Biryani                                                                                                                                                             |800.0                      |true       |
# |Churros, Cannelloni, Minestrone Soup, Hot Chocolate, Pink Sauce Pasta, Salsa, Veg Supreme Pizza                                                                                                                                                                  |800.0                      |true       |
# |Masala Dosa                                                                                                                                                                                                                                                      |300.0                      |false      |
# |MISSING                                                                                                                                                                                                                                                          |42.0                       |false      |
# |MISSING                                                                                                                                                                                                                                                          |42.0                       |false      |
# |MISSING                                                                                                                                                                                                                                                          |42.0                       |true       |
# |MISSING                                                                                                                                                                                                                                                          |42.0                       |false      |
# |MISSING                                                                                                                                                                                                                                                          |42.0                       |false      |
# |MISSING                                                                                                                                                                                                                                                          |42.0                       |false      |
# |MISSING                                                                                                                                                                                                                                                          |42.0                       |true       |
# | Koramangala bakasura ended up at an onesta in Banashankari as well!\nEvery visit                                                                                                                                                                                |42.0                       |false      |
# |MISSING                                                                                                                                                                                                                                                          |42.0                       |true       |
# | cosy                                                                                                                                                                                                                                                            |42.0                       |false      |
# |MISSING                                                                                                                                                                                                                                                          |42.0                       |true       |
# | they served in foil box.... unfortunately along with plastic spoon. May be they need to immediately change to a wooden spoon. We tried loaded fries and white sauce pasta...both were good. Will be a good adda for college kids.')                             |42.0                       |false      |
# |MISSING                                                                                                                                                                                                                                                          |42.0                       |true       |
# | a good hangout place but nahhh                                                                                                                                                                                                                                  |42.0                       |false      |
# |Mocktails, Peri Fries, Lasagne, Pizza, Chicken Bbq Wings, Virgin Mojito, Nachos                                                                                                                                                                                  |600.0                      |true       |
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------+-----------+
# only showing top 20 rows

# %%
# fill nulls with the non-null mean: means are 283 and 387 (approx)
noNull = zomato.fillna(zomato.agg(*(avg(colm.name).alias(colm.name) for colm in zomato.schema
                                    if (colm.dataType is IntegerType()) or (colm.dataType is FloatType()))).first().asDict())
noNull.select('votes', 'approx_cost(for two people)').show()
# Out:
# +-----+---------------------------+
# |votes|approx_cost(for two people)|
# +-----+---------------------------+
# |  775|                   387.4084|
# |  283|                   387.4084|
# |  787|                      800.0|
# |  918|                      800.0|
# |   88|                      300.0|
# |  166|                   387.4084|
# |  283|                   387.4084|
# |  286|                   387.4084|
# |  283|                   387.4084|
# |    8|                   387.4084|
# |  283|                   387.4084|
# | 2556|                   387.4084|
# |  283|                   387.4084|
# |  324|                   387.4084|
# |  283|                   387.4084|
# |  504|                   387.4084|
# |  283|                   387.4084|
# |  402|                   387.4084|
# |  283|                   387.4084|
# |  150|                      600.0|
# +-----+---------------------------+
# only showing top 20 rows

# %%
sc.stop()
